# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/Interview/Credit Sesame/'
# %ls
# Out:
# /content/drive/My Drive/Interview/Credit Sesame
# 'Data Scientist Take Home.pdf'          gitCommands.ipynb
# 'default of credit card clients.xls'   'Take Home Assessment.ipynb'
# 'default of credit card clients.xlsx'

# %%
# !pwd
# Out:
# /content/drive/My Drive/Interview/Credit Sesame

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Interview/Credit Sesame/.git/

# %%
#!git remote set-url origin https://carven198:Hello+1983@github.com/carven198/{Credit-Card-Default-Analysis}.git

# %%
#!git add -A .

# %%
# !git remote add origin https://carven198:Hello+1983@github.com/carven198/{Credit-Card-Default-Analysis}.git
#!git remote add origin https://github.com/carven198/Credit-Card-Default-Analysis.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://carven198:Hello+1983@github.com/carven198/{Credit-Card-Default-Analysis}.git (fetch)
# origin	https://carven198:Hello+1983@github.com/carven198/{Credit-Card-Default-Analysis}.git (push)

# %%
# !git config --global user.email 'carven198@gmail.com'
# !git config --global user.name 'carven198'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 7d12abd] First commit
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Take Home Assessment.ipynb (89%)

# %%
# !git push origin master
# Out:
# fatal: unable to access 'https://carven198:Hello+1983@github.com/carven198/{Credit-Card-Default-Analysis}.git/': The requested URL returned error: 400
